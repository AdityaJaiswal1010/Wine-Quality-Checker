# %%
import pandas as pd
import numpy as np
import matplotlib as plt
import mplfinance as mpf
# %matplotlib inline

# %%
stock_df=pd.read_excel('Stock_Price_data_set.xlsx')

# %%
stock_df
# Out:
#            Date        Open        High         Low       Close   Adj Close  \
# 0    2018-02-05  262.000000  267.899994  250.029999  254.259995  254.259995
# 1    2018-02-06  247.699997  266.700012  245.000000  265.720001  265.720001
# 2    2018-02-07  266.579987  272.450012  264.329987  264.559998  264.559998
# 3    2018-02-08  267.079987  267.619995  250.000000  250.100006  250.100006
# 4    2018-02-09  253.850006  255.800003  236.110001  249.470001  249.470001
# ...         ...         ...         ...         ...         ...         ...
# 1004 2022-01-31  401.970001  427.700012  398.200012  427.140015  427.140015
# 1005 2022-02-01  432.959991  458.480011  425.540009  457.130005  457.130005
# 1006 2022-02-02  448.250000  451.980011  426.480011  429.480011  429.480011
# 1007 2022-02-03  421.440002  429.260010  404.279999  405.600006  405.600006
# 1008 2022-02-04  407.309998  412.769989  396.640015  410.170013  410.170013
#
#         Volume
# 0     11896100
# 1     12595800
# ...

# %%
stock_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1009 entries, 0 to 1008
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Date       1009 non-null   datetime64[ns]
#  1   Open       1009 non-null   float64
#  2   High       1009 non-null   float64
#  3   Low        1009 non-null   float64
#  4   Close      1009 non-null   float64
#  5   Adj Close  1009 non-null   float64
#  6   Volume     1009 non-null   int64
# dtypes: datetime64[ns](1), float64(5), int64(1)
# memory usage: 55.3 KB

# %%
stock_df=stock_df.set_index('Date')

# %%
mpf.plot(stock_df,figratio=(40,30),type='candle',mav=(20),volume=True,tight_layout=True,title='Stock',style='yahoo')
# Out:
# C:\Users\ADITYA\anaconda3\lib\site-packages\mplfinance\_arg_validators.py:36: UserWarning:
#
# ...
#
#    WARNING: YOU ARE PLOTTING SO MUCH DATA THAT IT MAY NOT BE
#             POSSIBLE TO SEE DETAILS (Candles, Ohlc-Bars, Etc.)
#    For more information see:
#    - https://github.com/matplotlib/mplfinance/wiki/Plotting-Too-Much-Data
#
#    TO SILENCE THIS WARNING, set `type='line'` in `mpf.plot()`
#    OR set kwarg `warn_too_much_data=N` where N is an integer
#    LARGER than the number of data points you want to plot.
#
# ...
#   warnings.warn('\n\n ================================================================= '+

# %%
mpf.plot(stock_df.loc['2018-02-05':'2018-06-20'],figratio=(40,30),type='candle',mav=(20),volume=True,
         tight_layout=True,title='Stock',style='yahoo')

# %%
stock_df.head()
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2018-02-05  262.000000  267.899994  250.029999  254.259995  254.259995
# 2018-02-06  247.699997  266.700012  245.000000  265.720001  265.720001
# 2018-02-07  266.579987  272.450012  264.329987  264.559998  264.559998
# 2018-02-08  267.079987  267.619995  250.000000  250.100006  250.100006
# 2018-02-09  253.850006  255.800003  236.110001  249.470001  249.470001
#
#               Volume
# Date
# 2018-02-05  11896100
# 2018-02-06  12595800
# 2018-02-07   8981500
# 2018-02-08   9306700
# 2018-02-09  16906900

# %%
stock_df.tail()
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2022-01-31  401.970001  427.700012  398.200012  427.140015  427.140015
# 2022-02-01  432.959991  458.480011  425.540009  457.130005  457.130005
# 2022-02-02  448.250000  451.980011  426.480011  429.480011  429.480011
# 2022-02-03  421.440002  429.260010  404.279999  405.600006  405.600006
# 2022-02-04  407.309998  412.769989  396.640015  410.170013  410.170013
#
#               Volume
# Date
# 2022-01-31  20047500
# 2022-02-01  22542300
# 2022-02-02  14346000
# 2022-02-03   9905200
# 2022-02-04   7782400

# %%
stock_df.describe()
# Out:
#               Open         High          Low        Close    Adj Close  \
# count  1009.000000  1009.000000  1009.000000  1009.000000  1009.000000
# mean    419.059673   425.320703   412.374044   419.000733   419.000733
# std     108.537532   109.262960   107.555867   108.289999   108.289999
# min     233.919998   250.649994   231.229996   233.880005   233.880005
# 25%     331.489990   336.299988   326.000000   331.619995   331.619995
# 50%     377.769989   383.010010   370.880005   378.670013   378.670013
# 75%     509.130005   515.630005   502.529999   509.079987   509.079987
# max     692.349976   700.989990   686.090027   691.690002   691.690002
#
#              Volume
# count  1.009000e+03
# mean   7.570685e+06
# std    5.465535e+06
# min    1.144000e+06
# 25%    4.091900e+06
# 50%    5.934500e+06
# 75%    9.322400e+06
# max    5.890430e+07

# %%
stock_df.isna().any()
# Out:
# Open         False
# High         False
# Low          False
# Close        False
# Adj Close    False
# Volume       False
# dtype: bool

# %%
stock_df.isna().sum()
# Out:
# Open         0
# High         0
# Low          0
# Close        0
# Adj Close    0
# Volume       0
# dtype: int64

# %%
stock_df.shape
# Out:
# (1009, 6)

# %%
stock_df.duplicated().sum()
# Out:
# 0

# %%
import matplotlib.pyplot as plt

plt.subplot(2,3,1)
stock_df['Open'].plot(kind='box')

plt.subplot(2,3,2)
stock_df['Close'].plot(kind='box')

plt.subplot(2,3,3)
stock_df['High'].plot(kind='box')

plt.subplot(2,3,4)
stock_df['Low'].plot(kind='box')

plt.subplot(2,3,5)
stock_df['Adj Close'].plot(kind='box')

plt.subplot(2,3,6)
stock_df['Volume'].plot(kind='box')

plt.tight_layout()

# %%
stock_df['Volume'].max()
# Out:
# 58904300

# %%
def find_outliner_limits(column):
    Q1,Q3=stock_df[column].quantile([.25,.75])
    IQR=Q3-Q1
    
    high=Q3+(1.5*IQR)
    return (high,IQR)


high_vol,IQR=find_outliner_limits('Volume')
print("Volume : \n","Upper Limit : ",high_vol,"IQR : ",IQR)
# Out:
# Volume :
#  Upper Limit :  17168150.0 IQR :  5230500.0

# %%
#handling the outliner
stock_df.loc[stock_df['Volume']>high_vol,'Volume']=high_vol

# %%
stock_df['Volume'].plot(kind='box')
# Out:
# <AxesSubplot:>

# %%
stock_df.max()
# Out:
# Open         6.923500e+02
# High         7.009900e+02
# Low          6.860900e+02
# Close        6.916900e+02
# Adj Close    6.916900e+02
# Volume       1.716815e+07
# dtype: float64

# %%
stock_df.count()
# Out:
# Open         1009
# High         1009
# Low          1009
# Close        1009
# Adj Close    1009
# Volume       1009
# dtype: int64

# %%
mpf.plot(stock_df,figratio=(40,30),type='candle',mav=(20),volume=True,tight_layout=True,title='Stock',style='yahoo')
# Out:
# C:\Users\ADITYA\anaconda3\lib\site-packages\mplfinance\_arg_validators.py:36: UserWarning:
#
# ...
#
#    WARNING: YOU ARE PLOTTING SO MUCH DATA THAT IT MAY NOT BE
#             POSSIBLE TO SEE DETAILS (Candles, Ohlc-Bars, Etc.)
#    For more information see:
#    - https://github.com/matplotlib/mplfinance/wiki/Plotting-Too-Much-Data
#
#    TO SILENCE THIS WARNING, set `type='line'` in `mpf.plot()`
#    OR set kwarg `warn_too_much_data=N` where N is an integer
#    LARGER than the number of data points you want to plot.
#
# ...
#   warnings.warn('\n\n ================================================================= '+

# %%
mpf.plot(stock_df.loc['2018-02-05':'2018-06-20'],figratio=(40,30),type='candle',mav=(20),volume=True,
         tight_layout=True,title='Stock',style='yahoo')

# %%
stock_df
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2018-02-05  262.000000  267.899994  250.029999  254.259995  254.259995
# 2018-02-06  247.699997  266.700012  245.000000  265.720001  265.720001
# 2018-02-07  266.579987  272.450012  264.329987  264.559998  264.559998
# 2018-02-08  267.079987  267.619995  250.000000  250.100006  250.100006
# 2018-02-09  253.850006  255.800003  236.110001  249.470001  249.470001
# ...                ...         ...         ...         ...         ...
# 2022-01-31  401.970001  427.700012  398.200012  427.140015  427.140015
# 2022-02-01  432.959991  458.480011  425.540009  457.130005  457.130005
# 2022-02-02  448.250000  451.980011  426.480011  429.480011  429.480011
# 2022-02-03  421.440002  429.260010  404.279999  405.600006  405.600006
# 2022-02-04  407.309998  412.769989  396.640015  410.170013  410.170013
#
#               Volume
# Date
# 2018-02-05  11896100
# 2018-02-06  12595800
# 2018-02-07   8981500
# ...

# %%
stock_df.shape
# Out:
# (1009, 6)

# %%
#starting with ML model
x=stock_df[['Open','High','Low','Adj Close','Volume']]
x
# Out:
#                   Open        High         Low   Adj Close    Volume
# Date
# 2018-02-05  262.000000  267.899994  250.029999  254.259995  11896100
# 2018-02-06  247.699997  266.700012  245.000000  265.720001  12595800
# 2018-02-07  266.579987  272.450012  264.329987  264.559998   8981500
# 2018-02-08  267.079987  267.619995  250.000000  250.100006   9306700
# 2018-02-09  253.850006  255.800003  236.110001  249.470001  16906900
# ...                ...         ...         ...         ...       ...
# 2022-01-31  401.970001  427.700012  398.200012  427.140015  17168150
# 2022-02-01  432.959991  458.480011  425.540009  457.130005  17168150
# 2022-02-02  448.250000  451.980011  426.480011  429.480011  14346000
# 2022-02-03  421.440002  429.260010  404.279999  405.600006   9905200
# 2022-02-04  407.309998  412.769989  396.640015  410.170013   7782400
#
# [1009 rows x 5 columns]

# %%
y=stock_df[['Close']]
y
# Out:
#                  Close
# Date
# 2018-02-05  254.259995
# 2018-02-06  265.720001
# 2018-02-07  264.559998
# 2018-02-08  250.100006
# 2018-02-09  249.470001
# ...                ...
# 2022-01-31  427.140015
# 2022-02-01  457.130005
# 2022-02-02  429.480011
# 2022-02-03  405.600006
# 2022-02-04  410.170013
#
# [1009 rows x 1 columns]

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=0)
print(x_train.shape)
print(x_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (807, 5)
# (202, 5)
# (807, 1)
# (202, 1)

# %%
from sklearn.preprocessing import StandardScaler
scale=StandardScaler()
scale.fit_transform(x_train)
scale.transform(x_test)
# Out:
# array([[ 1.2737758 ,  1.23535036,  1.28553373,  1.2496754 , -1.09317633],
#        [-0.36873418, -0.37251329, -0.34119659, -0.35687985, -0.45787292],
#        [-0.45553938, -0.50752811, -0.49582827, -0.51931058,  0.22532912],
#        ...,
#        [-1.52362976, -1.50691247, -1.50264471, -1.47080843,  0.28627592],
#        [-1.0751969 , -1.05899125, -1.02144563, -1.03658694, -0.52581829],
#        [-0.09978466, -0.10549399, -0.13640932, -0.07074049,  0.10775327]])

# %%
from sklearn.linear_model import LinearRegression
reg=LinearRegression()

# %%
reg.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
m=reg.coef_
c=reg.intercept_
m,c
# Out:
# (array([[ 3.34946545e-15,  1.96615424e-16, -2.32636012e-15,
#           1.00000000e+00,  1.13586300e-20]]),
#  array([-1.1937118e-12]))

# %%
y_predicted_train=reg.predict(x_train)
y_predicted_test=reg.predict(x_test)
y_predicted_train,y_predicted_test
# Out:
# (array([[540.219971],
#         [513.969971],
#         [483.859985],
#         [348.410004],
#         [298.839996],
#         [352.190002],
#         [302.600006],
#         [677.719971],
#         [363.910004],
#         [397.5     ],
#         [374.600006],
#         [381.049988],
#         [518.909973],
#         [383.790009],
#         [521.869995],
#         [375.130005],
#         [555.309998],
#         [295.350006],
#         [482.880005],
#         [606.710022],
#         [396.720001],
#         [365.359985],
#         [364.559998],
#         [288.940002],
#         [499.100006],
#         [505.549988],
#         [368.329987],
#         [565.169983],
#         [358.100006],
#         [270.75    ],
#         [487.220001],
#         [502.779999],
#         [364.130005],
#         [301.049988],
#         [497.899994],
#         [319.75    ],
#         [339.100006],
#         [484.980011],
#         [344.709991],
#         [320.089996],
#         [353.540009],
# ...

# %%
#accuracy percent 
from sklearn.metrics import r2_score
r2_s=r2_score(y_train,y_predicted_train)
r2_s
# Out:
# 1.0

# %%
r2_s2=r2_score(y_test,y_predicted_test)
r2_s2
# Out:
# 1.0
